# %%
print("Hope AI")
# Out:
# Hope AI

# %%
input ("Enter your institute name :")B
# Out:
# Enter your institute name : Hope AI
# 'Hope AI'

# %%
input ("Enter your name: ")
input ("Enter your age: ") 
input ("Enter your school name: ")
input ("Enter your degree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru school
# Enter your degree:  B.E CSE
# 'B.E CSE'

# %%
a,b=43,34
print ("a =",a)
print ("b =",b)
print ("Add =",a+b)
# Out:
# a = 43
# b = 34
# Add = 77

# %%
a,b=43,34
print ("a =",a)
print ("b =",b)
print ("Sub =",a-b)
# Out:
# a = 43
# b = 34
# Sub = 9

# %%
a,b=63,97
print ("a =",a)
print ("b =",b)
print ("Mul =",a*b)
# Out:
# a = 63
# b = 97
# Mul = 6111

# %%
a,b=76,31
print ("a =",a)
print ("b =",b)
Div = float(a/b)
print ("Div =",Div)
# Out:
# a = 76
# b = 31
# Div = 2.4516129032258065

# %%
a,b=76,31
print ("a =",a)
print ("b =",b)
Div = int(a/b)
print ("Div =",Div)
# Out:
# a = 76
# b = 31
# Div = 2

# %%
a,b=76,31
print ("a =",a)
print ("b =",b)
Modulo  = (a%b)
print ("Modulo  =",Modulo )
# Out:
# a = 76
# b = 31
# Modulo  = 14

# %%
a,b=4,4
print ("a =",a)
print ("b =",b)
Power = a**b
print ("Div =",Power)
# Out:
# a = 4
# b = 4
# Div = 256
